# %% [markdown]
# <a href="https://colab.research.google.com/github/yearlyale/edd_1350_2021/blob/master/Lista_Circular_Simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Nodo:
    def __init__( self , dato, siguiente = None):
        self.dato = dato
        self.siguiente = siguiente
        
class ListaCircular( ):
	def __init__(self):
		self.__ref = None
		self.__size = 0

	def is_empty(self):
		return self.__size == 0

	def insert(self, value ):
		
		if self.__ref == None:
			self.__ref = Nodo(value)

		elif value >= self.__ref.dato and self.__ref.siguiente == None:
			self.__ref.siguiente = Nodo(value,self.__ref)
			self.__ref = self.__ref.siguiente

		elif value >= self.__ref.dato:
			self.__ref.siguiente = Nodo(value,self.__ref.siguiente)
			self.__ref = self.__ref.siguiente

		elif value <= self.__ref.dato and self.__ref.siguiente == None:
			self.__ref.siguiente = Nodo(value,self.__ref)

		elif value <= self.__ref.siguiente.dato:
			self.__ref.siguiente = Nodo(value,self.__ref.siguiente)

		else:
			curr_node = self.__ref.siguiente
			while curr_node.dato != self.__ref.dato:
				if value > curr_node.dato and value < curr_node.siguiente.dato:
					curr_node.siguiente = Nodo(value,curr_node.siguiente)
				curr_node = curr_node.siguiente

		self.__size += 1

	def transversal(self):
		curr_node = self.__ref.siguiente
		if self.__ref != None:
			if self.__ref.siguiente != None:
				for i in range(self.__size):
					print(curr_node.dato, "-->" , end="")
					curr_node = curr_node.siguiente
				print('\n')
			else:
				print(self.__ref.dato, "-->" , end="")
				print('\n')
		else:
			print('Lista vacia')

	def search(self, value ):
		curr_node = self.__ref
		if self.__ref != None:
			for i in range(self.__size):
				if curr_node.dato == value:
					return True
				curr_node = curr_node.siguiente
		return False

	def remove(self,value):

		curr_node = self.__ref
		if self.__ref != None:
			for i in range(self.__size):
				if curr_node.siguiente.dato == value:
					curr_node.siguiente = curr_node.siguiente.siguiente
					self.__size -= 1
					return None
				else:
					curr_node = curr_node.siguiente



x = ListaCircular()

x.insert(10)
x.transversal()
x.insert(20)
x.insert(54)
x.insert(5)
x.insert(25)

x.transversal()

print(x.search(14))
print(x.search(5))

x.remove(20)
x.remove(10)
x.remove(5)

x.transversal()
