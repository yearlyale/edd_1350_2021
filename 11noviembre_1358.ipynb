# %% [markdown]
# <a href="https://colab.research.google.com/github/yearlyale/edd_1350_2021/blob/master/11noviembre_1358.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Nodo:
    def __init__( self , dato ):
        self.__dato = dato
        self.__siguiente = None

    def get_dato( self ):
        return self.__dato

    def set_dato( self , d ):
        self.__dato = d

    def get_siguiente( self ):
        return self.__siguiente

    def set_siguiente( self , d ):
        self.__siguiente = d

    def show( self ):
        curr_node = self # Head
        print(" Inicio de la estructura ligada:")
        print("|" + str(curr_node.get_dato()) + "| -->" , end ="" )
        while( curr_node.get_siguiente() != None ):
            curr_node = curr_node.get_siguiente()
            print("|" + str(curr_node.get_dato() ) + "| -->" , end ="" )
        print("\nFin")


a = Nodo( 10 )
a.show()


a.set_siguiente(Nodo(20))
a.show()

a.get_siguiente().set_siguiente(Nodo(30))
a.show()


a.get_siguiente().get_siguiente().set_siguiente(Nodo(40))
a.show()


a.get_siguiente().get_siguiente().get_siguiente().set_siguiente(Nodo(50))
a.show()


a.set_dato(12)
a.show()



a.get_siguiente().get_siguiente().get_siguiente().set_dato(45)
a.show()


a.get_siguiente().get_siguiente().get_siguiente().get_siguiente().set_siguiente(Nodo(60))
a.show()


a.get_siguiente().set_dato(25)
a.show()



 

class Nodo:
    def __init__( self , dato ):
        self.dato = dato
        self.siguiente = None


a = Nodo( 10 )
print( a.dato )
print( a.siguiente )


a.siguiente = Nodo( 20 )



a.siguiente.siguiente=Nodo(30)


a.siguiente.siguiente.siguiente=Nodo(40)


a.siguiente.siguiente.siguiente.siguiente=Nodo(50)






curr_node = a
print(curr_node.dato , "-->" , end="")
while( curr_node.siguiente != None ):
    curr_node = curr_node.siguiente
    print(curr_node.dato, "-->" , end="")
print("")

# eliminar nodos 


a.siguiente.siguiente.siguiente.dato=45


a.siguiente.siguiente.dato = 35



a.siguiente.siguiente = a.siguiente.siguiente.siguiente 



a.siguiente = a.siguiente.siguiente.siguiente.siguiente
